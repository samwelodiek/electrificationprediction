# %%
import ee
import pandas as pd
import matplotlib.pyplot as plt

# 1. Initialize Google Earth Engine
try:
    ee.Initialize()
except Exception as e:
    print("Authentication required...")
    ee.Authenticate()
    ee.Initialize()

print("✅ Earth Engine Initialized.")

# 2. Define Function to Extract Data for Any Location
def get_ndvi_history(city_name, lat, lon, start_year=2000, end_year=2024):
    print(f"\n🌍 Fetching 24-year NDVI history for: {city_name}...")
    
    # Define location and buffer (5km radius around the point)
    point = ee.Geometry.Point([lon, lat])
    region = point.buffer(5000) 

    # Load MODIS Dataset (MOD13Q1) - 250m resolution, 16-day composites
    # We choose MODIS because it goes back to the year 2000 (Sentinel only starts 2015)
    dataset = ee.ImageCollection('MODIS/061/MOD13Q1') \
                .filter(ee.Filter.date(f'{start_year}-01-01', f'{end_year}-01-01')) \
                .select('NDVI')

    # Function to calculate mean NDVI for the region for each image
    def extract_ndvi(image):
        stats = image.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=region,
            scale=250,  # MODIS resolution
            maxPixels=1e9
        )
        # Return date and scaled NDVI (MODIS NDVI is scaled by 0.0001)
        return ee.Feature(None, {
            'date': image.date().format('YYYY-MM-dd'),
            'ndvi': stats.get('NDVI'),
            'city': city_name
        })

    # Fetch data from server
    timeseries = dataset.map(extract_ndvi).getInfo()

    # Convert to DataFrame
    data_list = [feat['properties'] for feat in timeseries['features']]
    df = pd.DataFrame(data_list)

    # Cleaning: Handle missing values and scale NDVI
    if not df.empty:
        df['date'] = pd.to_datetime(df['date'])
        df['ndvi'] = df['ndvi'] * 0.0001  # Apply scale factor
        df = df.dropna()
        df = df.sort_values('date')
    
    return df

# 3. Define Your Cities (Add as many as you want)
locations = [
    {"name": "Nyeri", "lat": -0.4192962, "lon": 36.9517005},
    {"name": "Nakuru", "lat": -0.3031, "lon": 36.0800},
    {"name": "Eldoret", "lat": 0.5143, "lon": 35.2698}
]

# 4. Loop Through Cities and Collect Data
all_data = []

for loc in locations:
    city_df = get_ndvi_history(loc["name"], loc["lat"], loc["lon"])
    
    if not city_df.empty:
        # Save individual city csv
        filename = f"{loc['name'].lower()}_ndvi_history.csv"
        city_df.to_csv(filename, index=False)
        print(f"   ✅ Saved {len(city_df)} rows to {filename}")
        
        # Add to main list for plotting
        all_data.append(city_df)
        
        # Plotting individual city
        plt.figure(figsize=(12, 4))
        plt.plot(city_df['date'], city_df['ndvi'], color='green', linewidth=0.5)
        plt.title(f'24-Year Crop Health (NDVI) - {loc["name"]}')
        plt.ylabel('NDVI (Vegetation Vigor)')
        plt.grid(True, alpha=0.3)
        plt.show()
    else:
        print(f"   ⚠️ No data found for {loc['name']}")

# 5. (Optional) Combine all into one large dataset for ML training
if all_data:
    master_df = pd.concat(all_data)
    master_df.to_csv("all_cities_yield_proxy.csv", index=False)
    print(f"\n🎉 Master dataset created with {len(master_df)} rows ready for Machine Learning.")
# Out:
# Authentication required...
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=RaDzTM5RYn0SJEehArP9bVjWlXHQjO_sfFuOK7yG4Fs&tc=8L66Qt891tATV4haL6jpJ6YH_Rh-fnfatNrTKTJHMs4&cc=dmsoWzPlXVLLYqqRuqLTk9GxFNCW41hIuCGmLe3M8V8>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=RaDzTM5RYn0SJEehArP9bVjWlXHQjO_sfFuOK7yG4Fs&tc=8L66Qt891tATV4haL6jpJ6YH_Rh-fnfatNrTKTJHMs4&cc=dmsoWzPlXVLLYqqRuqLTk9GxFNCW41hIuCGmLe3M8V8</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[2], line 7
#       6 try:
# ----> 7     ee.Initialize()
#       8 except Exception as e:
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\_utils.py:39, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      38       kwargs[new_key] = old_key_val
# ---> 39 return func(*args, **kwargs)
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\__init__.py:188, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     187 if credentials == 'persistent':
# --> 188   credentials = data.get_persistent_credentials()
#     189 if not project and credentials and hasattr(credentials, 'quota_project_id'):
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\data.py:237, in get_persistent_credentials()
#     236     return credentials
# --> 237 raise ee_exception.EEException(  # pylint: disable=raise-missing-from
#     238     'Please authorize access to your Earth Engine account by '
#     239     'running\n\nearthengine authenticate\n\n'
#     240     'in your command line, or ee.Authenticate() in Python, and then retry.'
#     241 )
#
# EEException: Please authorize access to your Earth Engine account by running
#
# earthengine authenticate
#
# in your command line, or ee.Authenticate() in Python, and then retry.
#
# During handling of the above exception, another exception occurred:
#
# HttpError                                 Traceback (most recent call last)
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\data.py:349, in _execute_cloud_call(call, num_retries)
#     348 try:
# --> 349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://earthengine.googleapis.com/v1/projects/672741505411/algorithms?prettyPrint=false&alt=json returned "Project ee-samwelodiek is not registered to use Earth Engine. Visit https://console.cloud.google.com/earth-engine/configuration?project=ee-samwelodiek to register your project. See https://developers.google.com/earth-engine/guides/access for more details. If you have previously registered your project for noncommercial use and lost access, you will need to re-verify your eligibility. See the https://developers.google.com/earth-engine/guides/access#configuring_noncommercial_access for more details.". Details: "Project ee-samwelodiek is not registered to use Earth Engine. Visit https://console.cloud.google.com/earth-engine/configuration?project=ee-samwelodiek to register your project. See https://developers.google.com/earth-engine/guides/access for more details. If you have previously registered your project for noncommercial use and lost access, you will need to re-verify your eligibility. See the https://developers.google.com/earth-engine/guides/access#configuring_noncommercial_access for more details.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[2], line 11
#       9     print("Authentication required...")
#      10     ee.Authenticate()
# ---> 11     ee.Initialize()
#      13 print("✅ Earth Engine Initialized.")
#      15 # 2. Define Function to Extract Data for Any Location
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\_utils.py:39, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      37     if new_key not in kwargs:
#      38       kwargs[new_key] = old_key_val
# ---> 39 return func(*args, **kwargs)
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\__init__.py:233, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     227   if (
#     228       (adc_err in str(e))
#     229       or (matches and oauth.is_sdk_project(matches[1]))
#     230       or (oauth_project_err in str(e))
#     231   ):
#     232     raise EEException(NO_PROJECT_EXCEPTION) from None
# --> 233   raise e
#     235 for dynamic_class in _DYNAMIC_CLASSES:
#     236   dynamic_class.initialize()
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\__init__.py:215, in Initialize(credentials, url, cloud_api_key, http_transport, project)
#     213 # Initialize the dynamically loaded functions on the objects that want them.
#     214 try:
# --> 215   ApiFunction.initialize()
#     216 except EEException as e:
#     217   # We tried to detect missing projects before initialization, but some cases
#     218   # like Colab hide the project, so check errors from missing projects too.
#     219   adc_err = 'authenticating by using local Application Default Credentials'
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\apifunction.py:163, in ApiFunction.initialize(cls)
#     161 """Initializes the list of signatures from the Earth Engine front-end."""
#     162 if not cls._api:
# --> 163   signatures = data.getAlgorithms()
#     164   api = {}
#     165   for name, sig in signatures.items():
#     166     # Strip type parameters.
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\data.py:1442, in getAlgorithms()
#    1437     print(
#    1438         '*** Earth Engine ***',
#    1439         response[_INIT_MESSAGE_HEADER],
#    1440         file=sys.stderr)
#    1441 call.add_response_callback(inspect)
# -> 1442 return _cloud_api_utils.convert_algorithms(_execute_cloud_call(call))
#
# File c:\Users\samwe\Desktop\samwelodiek\.venv\Lib\site-packages\ee\data.py:351, in _execute_cloud_call(call, num_retries)
#     349   return call.execute(num_retries=num_retries)
#     350 except googleapiclient.errors.HttpError as e:
# --> 351   raise _translate_cloud_exception(e)
#
# EEException: Project ee-samwelodiek is not registered to use Earth Engine. Visit https://console.cloud.google.com/earth-engine/configuration?project=ee-samwelodiek to register your project. See https://developers.google.com/earth-engine/guides/access for more details. If you have previously registered your project for noncommercial use and lost access, you will need to re-verify your eligibility. See the https://developers.google.com/earth-engine/guides/access#configuring_noncommercial_access for more details.
